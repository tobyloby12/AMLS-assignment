# %% [markdown]
# # Creating a classification model and comparing classifiers and feature extraction techniques

# %%
# importing libraries
import os
import cv2
from skimage.feature import hog
import matplotlib.pyplot as plt
from skimage import data, exposure
import numpy as np
import pywt
import pywt.data
import pandas as pd
from tqdm.auto import tqdm
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn import svm
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.pipeline import Pipeline
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV
from sklearn.metrics import ConfusionMatrixDisplay

# %%
# first feature selection technique is HOG
def calculate_hog_features(image):
    hog_image = cv2.resize(image, (512, 256), interpolation=cv2.INTER_AREA)
    fd, hog_image = hog(hog_image, orientations=8, pixels_per_cell=(16, 16), cells_per_block=(1, 1), visualize=True)
    return fd, hog_image

# %%
# showing example of what the hog features show

img = cv2.imread('./dataset/image/IMAGE_0000.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

fd, hog_image = calculate_hog_features(img)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8), sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(img, cmap=plt.cm.gray)
ax1.set_title('Input image')

# Rescale histogram for better display
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))

ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)
ax2.set_title('Histogram of Oriented Gradients')
plt.show()

# %%
# second feature is wavelets with 'haar' feature

# adapting function so that I can apply the transform multiple times
def wavelet_feature(original, iterations):
    for i in range(iterations):
        coeffs = pywt.dwt2(original, 'haar')
        LL, (LH, HL, HH) = coeffs
        original = LL
    return coeffs

# %%
# Load image
original = cv2.imread('./dataset/image/IMAGE_0000.jpg')
original = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)

# Wavelet transform of image, and plot approximation and details
titles = ['Approximation', ' Horizontal detail',
          'Vertical detail', 'Diagonal detail']
coeffs = wavelet_feature(original, 2)
LL, (LH, HL, HH) = coeffs
fig = plt.figure(figsize=(12, 3))
for i, a in enumerate([LL, LH, HL, HH]):
    ax = fig.add_subplot(1, 4, i + 1)
    ax.imshow(a, interpolation="nearest", cmap=plt.cm.gray)
    ax.set_title(titles[i], fontsize=10)
    ax.set_xticks([])
    ax.set_yticks([])

fig.tight_layout()
plt.show()

# %%
import pywt
import cv2
import numpy as np
import matplotlib.pyplot as plt

original = cv2.imread('./dataset/image/IMAGE_0000.jpg')
original = cv2.resize(original, (256, 256))
original = original
original = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)

n = 2
w = 'haar'
coeffs = pywt.wavedec2(original, wavelet=w, level=n)

# for detail_level in range(n):
#     coeffs[detail_level + 1] = [d/255 for d in coeffs[detail_level + 1]]

arr, coeffs_slices = pywt.coeffs_to_array(coeffs)

plt.imshow(arr, cmap='gray_r')
plt.show()

# %%
# saving features for comparisons
# creating directories for features to go in
try:
    os.mkdir('./features_task_a')
except:
    print('Directory already created')
try:
    os.mkdir('./features_task_a/train')
except:
    print('Directory already created')
try:
    os.mkdir('./features_task_a/test')
except:
    print('Directory already created')
# Out:
# Directory already created
# Directory already created
# Directory already created

# %%
# turning classes into numbers so that it can be used as a binary classifier
classes = {'meningioma_tumor': 0, 'no_tumor': 1, 'glioma_tumor': 2, 'pituitary_tumor': 3}

# function to extract and save features for future use
def feature_extraction(train_test):
    df = pd.read_csv(f'./dataset/{train_test}.csv')
    hog_features = []
    wavelet_features_2 = []
    wavelet_features_3 = []
    labels = []
    for row in tqdm(df.iterrows()):
        image_name = row[1][0]
        label = row[1][1]
        # opening image
        img = cv2.imread(f'./dataset/{train_test}/{image_name}')
        
        # grayscaling image
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        # normalising images between 0 and 1
        img = img/255

        # resizing images to 256 pixels square

        img = cv2.resize(img, (256, 256), interpolation = cv2.INTER_AREA)


        # creating features and appending to arrays
        features, hog_image = calculate_hog_features(img)
        hog_features.append(features)

        features = wavelet_feature(img, 2)
        LL, (LH, HL, HH) = features
        wavelet_features_2.append(LL.flatten())

        features = wavelet_feature(img, 3)
        LL, (LH, HL, HH) = features
        wavelet_features_3.append(LL.flatten())

        # saving labels
        labels.append(classes[label])

    # saving so that it doesnt need to be run multiple times
    try:
        np.save(f'./features_task_a/{train_test}/hog', hog_features)
    except:
        print("Features already created")
    
    try:
        np.save(f'./features_task_a/{train_test}/wavelet_3x', wavelet_features_3)
    except:
        print("Features already created")

    try:
        np.save(f'./features_task_a/{train_test}/labels', labels)
    except:
        print("Features already created")

    try:
        np.save(f'./features_task_a/{train_test}/wavelet_2x', wavelet_features_2)
    except:
        print("Features already created")

# %%
# running feaeture extraction
feature_extraction('train')
feature_extraction('test')
# Out:
# 2750it [02:54, 15.80it/s]
# 900it [00:56, 15.91it/s]

# %% [markdown]
# # Training and Evaluating SVM RBF Classifier

# %%
# creating model and evaluating
# features will be an array of features which will be concatenated together from different feature extraction methods
def classifier(features_selected):
    x_train = []
    x_test = []
    for feature_type in features_selected:
        # loading features
        x_train.append(np.load(f'./features_task_a/train/{feature_type}.npy'))
        x_test.append(np.load(f'./features_task_a/test/{feature_type}.npy'))
    x_train = tuple(x_train)
    x_test = tuple(x_test)
    x_train = np.concatenate(x_train, axis=1)
    x_test = np.concatenate(x_test, axis=1)
    y_train = np.load(f'./features_task_a/train/labels.npy')
    y_test = np.load(f'./features_task_a/test/labels.npy')
    # SVM model

    scalar = StandardScaler()
    pca = PCA()
    svc = svm.SVC()

    pipe = Pipeline(steps=[("scalar", scalar), ("pca", pca), ("svc", svc)])
    # parameters = [
    #     {
    #         'svc__kernel':['rbf'], 
    #         'svc__C':[0.1, 1, 10, 100], 
    #         'svc__gamma':[1, 0.1, 0.01, 0.001, 0.0001], 
    #         'pca__n_components': [10, 50, 100, 200]
    #     }, 
    #     {
    #         'svc__kernel':['poly'], 
    #         'svc__C':[0.1, 1, 10, 100], 
    #         'svc__gamma':[1, 0.1, 0.01, 0.001, 0.0001], 
    #         'pca__n_components': [10, 50, 100, 200], 
    #         'svc__degree': [1, 2, 3, 4, 5]
    #     }
    # ]

    parameters = {
            'svc__kernel':['rbf'], 
            'svc__C':[10], 
            'svc__gamma':[0.01, 0.001, 0.0001], 
            'pca__n_components': [0.9, 0.95, 0.99, 50, 100]
        }
    grid = GridSearchCV(pipe, parameters, refit='accuracy',  verbose = 3, n_jobs=1, scoring=['accuracy'])

    # grid = HalvingGridSearchCV(pipe, parameters, verbose=3)
    grid.fit(x_train, y_train)


    # # ada boost model
    # scalar = StandardScaler()
    # pca = PCA()
    # clf = AdaBoostClassifier()

    # pipe = Pipeline(steps=[("scalar", scalar), ("pca", pca), ("adaboost", clf)])

    # parameters = {
    #     'pca__n_components': [10, 50, 100, 200],
    #     'adaboost__n_estimators': [200, 300, 400]
    # }

    # grid = GridSearchCV(pipe, parameters, refit=True, verbose = 3)
    # grid.fit(x_train, y_train)
    

    return grid, x_test, y_test

# %%
import pickle

parameters = ['hog', 'wavelet_3x', 'wavelet_2x']
grid, x_test, y_test = classifier(parameters)


filename = f"./models/{'multi'.join(parameters)}.sav"
pickle.dump(grid, open(filename, 'wb'))
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END pca__n_components=0.9, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.349) total time=  16.3s
# [CV 2/5] END pca__n_components=0.9, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.365) total time=  16.3s
# [CV 3/5] END pca__n_components=0.9, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.425) total time=  16.1s
# [CV 4/5] END pca__n_components=0.9, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.285) total time=  16.0s
# [CV 5/5] END pca__n_components=0.9, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.442) total time=  15.9s
# [CV 1/5] END pca__n_components=0.9, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.902) total time=  16.0s
# [CV 2/5] END pca__n_components=0.9, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.876) total time=  16.1s
# [CV 3/5] END pca__n_components=0.9, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.907) total time=  16.2s
# [CV 4/5] END pca__n_components=0.9, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.885) total time=  15.9s
# [CV 5/5] END pca__n_components=0.9, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.915) total time=  16.1s
# [CV 1/5] END pca__n_components=0.9, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.887) total time=  15.5s
# [CV 2/5] END pca__n_components=0.9, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.918) total time=  15.5s
# [CV 3/5] END pca__n_components=0.9, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.938) total time=  15.6s
# [CV 4/5] END pca__n_components=0.9, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.929) total time=  15.5s
# [CV 5/5] END pca__n_components=0.9, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.929) total time=  15.5s
# [CV 1/5] END pca__n_components=0.95, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.335) total time=  16.4s
# [CV 2/5] END pca__n_components=0.95, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.364) total time=  16.9s
# [CV 3/5] END pca__n_components=0.95, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.407) total time=  16.3s
# [CV 4/5] END pca__n_components=0.95, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.420) total time=  16.6s
# [CV 5/5] END pca__n_components=0.95, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.407) total time=  16.6s
# [CV 1/5] END pca__n_components=0.95, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.889) total time=  16.4s
# [CV 2/5] END pca__n_components=0.95, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.864) total time=  16.3s
# [CV 3/5] END pca__n_components=0.95, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.895) total time=  16.4s
# [CV 4/5] END pca__n_components=0.95, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.871) total time=  16.7s
# [CV 5/5] END pca__n_components=0.95, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.911) total time=  16.5s
# [CV 1/5] END pca__n_components=0.95, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.887) total time=  15.8s
# [CV 2/5] END pca__n_components=0.95, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.913) total time=  15.8s
# [CV 3/5] END pca__n_components=0.95, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.938) total time=  15.8s
# [CV 4/5] END pca__n_components=0.95, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.922) total time=  16.0s
# [CV 5/5] END pca__n_components=0.95, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.929) total time=  16.0s
# [CV 1/5] END pca__n_components=0.99, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.335) total time=  17.6s
# [CV 2/5] END pca__n_components=0.99, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.353) total time=  17.4s
# [CV 3/5] END pca__n_components=0.99, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.407) total time=  17.6s
# [CV 4/5] END pca__n_components=0.99, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.418) total time=  17.6s
# [CV 5/5] END pca__n_components=0.99, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.405) total time=  17.6s
# [CV 1/5] END pca__n_components=0.99, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.869) total time=  17.4s
# [CV 2/5] END pca__n_components=0.99, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.860) total time=  17.5s
# [CV 3/5] END pca__n_components=0.99, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.887) total time=  17.5s
# [CV 4/5] END pca__n_components=0.99, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.856) total time=  17.7s
# [CV 5/5] END pca__n_components=0.99, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.907) total time=  17.5s
# [CV 1/5] END pca__n_components=0.99, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.891) total time=  16.8s
# [CV 2/5] END pca__n_components=0.99, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.909) total time=  16.7s
# [CV 3/5] END pca__n_components=0.99, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.935) total time=  16.9s
# [CV 4/5] END pca__n_components=0.99, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.916) total time=  17.0s
# [CV 5/5] END pca__n_components=0.99, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.925) total time=  16.7s
# [CV 1/5] END pca__n_components=50, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.793) total time=   1.1s
# [CV 2/5] END pca__n_components=50, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.718) total time=   1.2s
# [CV 3/5] END pca__n_components=50, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.771) total time=   1.2s
# [CV 4/5] END pca__n_components=50, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.744) total time=   1.2s
# [CV 5/5] END pca__n_components=50, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.751) total time=   1.2s
# [CV 1/5] END pca__n_components=50, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.913) total time=   1.1s
# [CV 2/5] END pca__n_components=50, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.916) total time=   1.1s
# [CV 3/5] END pca__n_components=50, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.931) total time=   1.1s
# [CV 4/5] END pca__n_components=50, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.907) total time=   1.1s
# [CV 5/5] END pca__n_components=50, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.933) total time=   1.1s
# [CV 1/5] END pca__n_components=50, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.844) total time=   0.9s
# [CV 2/5] END pca__n_components=50, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.900) total time=   0.9s
# [CV 3/5] END pca__n_components=50, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.913) total time=   1.0s
# [CV 4/5] END pca__n_components=50, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.924) total time=   0.9s
# [CV 5/5] END pca__n_components=50, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.909) total time=   0.9s
# [CV 1/5] END pca__n_components=100, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.542) total time=   1.7s
# [CV 2/5] END pca__n_components=100, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.675) total time=   1.8s
# [CV 3/5] END pca__n_components=100, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.702) total time=   1.7s
# [CV 4/5] END pca__n_components=100, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.675) total time=   1.7s
# [CV 5/5] END pca__n_components=100, svc__C=10, svc__gamma=0.01, svc__kernel=rbf; accuracy: (test=0.667) total time=   1.7s
# [CV 1/5] END pca__n_components=100, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.905) total time=   1.7s
# [CV 2/5] END pca__n_components=100, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.915) total time=   1.6s
# [CV 3/5] END pca__n_components=100, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.933) total time=   1.7s
# [CV 4/5] END pca__n_components=100, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.911) total time=   1.7s
# [CV 5/5] END pca__n_components=100, svc__C=10, svc__gamma=0.001, svc__kernel=rbf; accuracy: (test=0.936) total time=   1.7s
# [CV 1/5] END pca__n_components=100, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.864) total time=   1.4s
# [CV 2/5] END pca__n_components=100, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.913) total time=   1.4s
# [CV 3/5] END pca__n_components=100, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.918) total time=   1.4s
# [CV 4/5] END pca__n_components=100, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.938) total time=   1.4s
# [CV 5/5] END pca__n_components=100, svc__C=10, svc__gamma=0.0001, svc__kernel=rbf; accuracy: (test=0.922) total time=   1.4s

# %%
# print best parameter after tuning
print(grid.best_params_)
 
# print how our model looks after hyper-parameter tuning
print(grid.best_estimator_)
# Out:
# {'pca__n_components': 0.9, 'svc__C': 10, 'svc__gamma': 0.0001, 'svc__kernel': 'rbf'}
# Pipeline(steps=[('scalar', StandardScaler()), ('pca', PCA(n_components=0.9)),
#                 ('svc', SVC(C=10, gamma=0.0001))])

# %%
from sklearn.metrics import ConfusionMatrixDisplay

confusion_matrix = ConfusionMatrixDisplay.from_estimator(grid, x_test, y_test, normalize='true')
confusion_matrix.figure_.savefig('./confusion_matrix_multi_SVM.png')
pred = grid.predict(x_test)
score = accuracy_score(y_test, pred)
print('accuracy: ', score)

# print classification report
print(classification_report(y_test, pred))
plt.show()
# Out:
# accuracy:  0.9277777777777778
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91       258
#            1       0.83      0.89      0.86       129
#            2       0.97      0.91      0.94       257
#            3       0.96      0.98      0.97       256
#
#     accuracy                           0.93       900
#    macro avg       0.92      0.92      0.92       900
# weighted avg       0.93      0.93      0.93       900

# %% [markdown]
# # Evaluating Random forest algorithm

# %%
# creating model and evaluating
# features will be an array of features which will be concatenated together from different feature extraction methods
def random_forrest_classifier(features_selected):
    x_train = []
    x_test = []
    for feature_type in features_selected:
        # loading features
        x_train.append(np.load(f'./features_task_a/train/{feature_type}.npy'))
        x_test.append(np.load(f'./features_task_a/test/{feature_type}.npy'))
    x_train = tuple(x_train)
    x_test = tuple(x_test)
    x_train = np.concatenate(x_train, axis=1)
    x_test = np.concatenate(x_test, axis=1)
    y_train = np.load(f'./features_task_a/train/labels.npy')
    y_test = np.load(f'./features_task_a/test/labels.npy')
    # SVM model

    scalar = StandardScaler()
    pca = PCA()
    clf = RandomForestClassifier()

    pipe = Pipeline(steps=[("scalar", scalar), ("pca", pca), ("clf", clf)])

    parameters = {
            'clf__n_estimators': [50, 100,],
            'clf__bootstrap': [True],
            'pca__n_components': [50]
        }
    grid = GridSearchCV(pipe, parameters, refit='accuracy',  verbose = 3, n_jobs=1, scoring=['accuracy'])

    # grid = HalvingGridSearchCV(pipe, parameters, verbose=3)
    grid.fit(x_train, y_train)
    

    return grid, x_test, y_test

# %%
import pickle

parameters = ['hog', 'wavelet_3x', 'wavelet_2x']
forest_model, x_test, y_test = random_forrest_classifier(parameters)


filename = f"./models/{'multiRandomForest'.join(parameters)}.sav"
pickle.dump(forest_model, open(filename, 'wb'))
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END clf__bootstrap=True, clf__n_estimators=50, pca__n_components=50; accuracy: (test=0.862) total time=   1.1s
# [CV 2/5] END clf__bootstrap=True, clf__n_estimators=50, pca__n_components=50; accuracy: (test=0.896) total time=   1.1s
# [CV 3/5] END clf__bootstrap=True, clf__n_estimators=50, pca__n_components=50; accuracy: (test=0.891) total time=   1.1s
# [CV 4/5] END clf__bootstrap=True, clf__n_estimators=50, pca__n_components=50; accuracy: (test=0.898) total time=   1.2s
# [CV 5/5] END clf__bootstrap=True, clf__n_estimators=50, pca__n_components=50; accuracy: (test=0.909) total time=   1.1s
# [CV 1/5] END clf__bootstrap=True, clf__n_estimators=100, pca__n_components=50; accuracy: (test=0.875) total time=   1.5s
# [CV 2/5] END clf__bootstrap=True, clf__n_estimators=100, pca__n_components=50; accuracy: (test=0.893) total time=   1.5s
# [CV 3/5] END clf__bootstrap=True, clf__n_estimators=100, pca__n_components=50; accuracy: (test=0.905) total time=   1.5s
# [CV 4/5] END clf__bootstrap=True, clf__n_estimators=100, pca__n_components=50; accuracy: (test=0.895) total time=   1.5s
# [CV 5/5] END clf__bootstrap=True, clf__n_estimators=100, pca__n_components=50; accuracy: (test=0.918) total time=   1.5s

# %%
# print best parameter after tuning
print(forest_model.best_params_)
 
# print how our model looks after hyper-parameter tuning
print(forest_model.best_estimator_)
# Out:
# {'clf__bootstrap': True, 'clf__n_estimators': 100, 'pca__n_components': 50}
# Pipeline(steps=[('scalar', StandardScaler()), ('pca', PCA(n_components=50)),
#                 ('clf', RandomForestClassifier())])

# %%
plot_confusion_matrix(forest_model, x_test, y_test, normalize='true')
plt.show()

confusion_matrix = ConfusionMatrixDisplay.from_estimator(forest_model, x_test, y_test, normalize='true')
confusion_matrix.figure_.savefig('./confusion_matrix_multi_SVM.png')
pred = forest_model.predict(x_test)
score = accuracy_score(y_test, pred)
print('accuracy: ', score)

# print classification report
print(classification_report(y_test, pred))
plt.show()
# Out:
# C:\Users\Gebruiker\.conda\envs\AMLS-assigment\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# accuracy:  0.8877777777777778
#               precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85       258
#            1       0.79      0.97      0.87       129
#            2       0.93      0.82      0.87       257
#            3       0.93      0.97      0.95       256
#
#     accuracy                           0.89       900
#    macro avg       0.88      0.90      0.88       900
# weighted avg       0.89      0.89      0.89       900

# %% [markdown]
# # Training and evaluating KNN classifier

# %%
# creating model and evaluating
# features will be an array of features which will be concatenated together from different feature extraction methods
def random_KNN_classifier(features_selected):
    x_train = []
    x_test = []
    for feature_type in features_selected:
        # loading features
        x_train.append(np.load(f'./features_task_a/train/{feature_type}.npy'))
        x_test.append(np.load(f'./features_task_a/test/{feature_type}.npy'))
    x_train = tuple(x_train)
    x_test = tuple(x_test)
    x_train = np.concatenate(x_train, axis=1)
    x_test = np.concatenate(x_test, axis=1)
    y_train = np.load(f'./features_task_a/train/labels.npy')
    y_test = np.load(f'./features_task_a/test/labels.npy')
    # SVM model

    scalar = StandardScaler()
    pca = PCA()
    clf = KNeighborsClassifier()

    pipe = Pipeline(steps=[("scalar", scalar), ("pca", pca), ("clf", clf)])

    parameters = {
            'clf__n_neighbors': [1, 2, 3, 4, 5],
            'pca__n_components': [50, 100, 150]
        }
    grid = GridSearchCV(pipe, parameters, refit='accuracy',  verbose = 3, n_jobs=1, scoring=['accuracy'])

    # grid = HalvingGridSearchCV(pipe, parameters, verbose=3)
    grid.fit(x_train, y_train)
    

    return grid, x_test, y_test

# %%
import pickle

parameters = ['hog', 'wavelet_3x', 'wavelet_2x']
KNN_model, x_test, y_test = random_KNN_classifier(parameters)


filename = f"./models/{'KNN'.join(parameters)}.sav"
pickle.dump(KNN_model, open(filename, 'wb'))
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END clf__n_neighbors=1, pca__n_components=50; accuracy: (test=0.862) total time=   0.8s
# [CV 2/5] END clf__n_neighbors=1, pca__n_components=50; accuracy: (test=0.889) total time=   0.8s
# [CV 3/5] END clf__n_neighbors=1, pca__n_components=50; accuracy: (test=0.931) total time=   0.8s
# [CV 4/5] END clf__n_neighbors=1, pca__n_components=50; accuracy: (test=0.918) total time=   0.8s
# [CV 5/5] END clf__n_neighbors=1, pca__n_components=50; accuracy: (test=0.925) total time=   0.8s
# [CV 1/5] END clf__n_neighbors=1, pca__n_components=100; accuracy: (test=0.871) total time=   1.3s
# [CV 2/5] END clf__n_neighbors=1, pca__n_components=100; accuracy: (test=0.893) total time=   1.3s
# [CV 3/5] END clf__n_neighbors=1, pca__n_components=100; accuracy: (test=0.942) total time=   1.3s
# [CV 4/5] END clf__n_neighbors=1, pca__n_components=100; accuracy: (test=0.920) total time=   1.3s
# [CV 5/5] END clf__n_neighbors=1, pca__n_components=100; accuracy: (test=0.935) total time=   1.3s
# [CV 1/5] END clf__n_neighbors=1, pca__n_components=150; accuracy: (test=0.864) total time=   1.7s
# [CV 2/5] END clf__n_neighbors=1, pca__n_components=150; accuracy: (test=0.891) total time=   1.6s
# [CV 3/5] END clf__n_neighbors=1, pca__n_components=150; accuracy: (test=0.922) total time=   1.7s
# [CV 4/5] END clf__n_neighbors=1, pca__n_components=150; accuracy: (test=0.913) total time=   1.7s
# [CV 5/5] END clf__n_neighbors=1, pca__n_components=150; accuracy: (test=0.931) total time=   1.7s
# [CV 1/5] END clf__n_neighbors=2, pca__n_components=50; accuracy: (test=0.840) total time=   0.8s
# [CV 2/5] END clf__n_neighbors=2, pca__n_components=50; accuracy: (test=0.869) total time=   0.8s
# [CV 3/5] END clf__n_neighbors=2, pca__n_components=50; accuracy: (test=0.911) total time=   0.8s
# [CV 4/5] END clf__n_neighbors=2, pca__n_components=50; accuracy: (test=0.880) total time=   0.8s
# [CV 5/5] END clf__n_neighbors=2, pca__n_components=50; accuracy: (test=0.902) total time=   0.8s
# [CV 1/5] END clf__n_neighbors=2, pca__n_components=100; accuracy: (test=0.838) total time=   1.3s
# [CV 2/5] END clf__n_neighbors=2, pca__n_components=100; accuracy: (test=0.887) total time=   1.3s
# [CV 3/5] END clf__n_neighbors=2, pca__n_components=100; accuracy: (test=0.925) total time=   1.3s
# [CV 4/5] END clf__n_neighbors=2, pca__n_components=100; accuracy: (test=0.884) total time=   1.3s
# [CV 5/5] END clf__n_neighbors=2, pca__n_components=100; accuracy: (test=0.907) total time=   1.3s
# [CV 1/5] END clf__n_neighbors=2, pca__n_components=150; accuracy: (test=0.838) total time=   1.6s
# [CV 2/5] END clf__n_neighbors=2, pca__n_components=150; accuracy: (test=0.880) total time=   1.7s
# [CV 3/5] END clf__n_neighbors=2, pca__n_components=150; accuracy: (test=0.925) total time=   1.7s
# [CV 4/5] END clf__n_neighbors=2, pca__n_components=150; accuracy: (test=0.884) total time=   1.7s
# [CV 5/5] END clf__n_neighbors=2, pca__n_components=150; accuracy: (test=0.904) total time=   1.6s
# [CV 1/5] END clf__n_neighbors=3, pca__n_components=50; accuracy: (test=0.831) total time=   0.8s
# [CV 2/5] END clf__n_neighbors=3, pca__n_components=50; accuracy: (test=0.855) total time=   0.8s
# [CV 3/5] END clf__n_neighbors=3, pca__n_components=50; accuracy: (test=0.887) total time=   0.8s
# [CV 4/5] END clf__n_neighbors=3, pca__n_components=50; accuracy: (test=0.876) total time=   0.8s
# [CV 5/5] END clf__n_neighbors=3, pca__n_components=50; accuracy: (test=0.889) total time=   0.8s
# [CV 1/5] END clf__n_neighbors=3, pca__n_components=100; accuracy: (test=0.818) total time=   1.3s
# [CV 2/5] END clf__n_neighbors=3, pca__n_components=100; accuracy: (test=0.856) total time=   1.3s
# [CV 3/5] END clf__n_neighbors=3, pca__n_components=100; accuracy: (test=0.900) total time=   1.3s
# [CV 4/5] END clf__n_neighbors=3, pca__n_components=100; accuracy: (test=0.871) total time=   1.3s
# [CV 5/5] END clf__n_neighbors=3, pca__n_components=100; accuracy: (test=0.902) total time=   1.3s
# [CV 1/5] END clf__n_neighbors=3, pca__n_components=150; accuracy: (test=0.820) total time=   1.6s
# [CV 2/5] END clf__n_neighbors=3, pca__n_components=150; accuracy: (test=0.853) total time=   1.7s
# [CV 3/5] END clf__n_neighbors=3, pca__n_components=150; accuracy: (test=0.902) total time=   1.7s
# [CV 4/5] END clf__n_neighbors=3, pca__n_components=150; accuracy: (test=0.871) total time=   1.6s
# [CV 5/5] END clf__n_neighbors=3, pca__n_components=150; accuracy: (test=0.902) total time=   1.6s
# [CV 1/5] END clf__n_neighbors=4, pca__n_components=50; accuracy: (test=0.822) total time=   0.8s
# [CV 2/5] END clf__n_neighbors=4, pca__n_components=50; accuracy: (test=0.835) total time=   0.8s
# [CV 3/5] END clf__n_neighbors=4, pca__n_components=50; accuracy: (test=0.884) total time=   0.8s
# [CV 4/5] END clf__n_neighbors=4, pca__n_components=50; accuracy: (test=0.864) total time=   0.8s
# [CV 5/5] END clf__n_neighbors=4, pca__n_components=50; accuracy: (test=0.895) total time=   0.8s
# [CV 1/5] END clf__n_neighbors=4, pca__n_components=100; accuracy: (test=0.809) total time=   1.3s
# [CV 2/5] END clf__n_neighbors=4, pca__n_components=100; accuracy: (test=0.845) total time=   1.3s
# [CV 3/5] END clf__n_neighbors=4, pca__n_components=100; accuracy: (test=0.891) total time=   1.2s
# [CV 4/5] END clf__n_neighbors=4, pca__n_components=100; accuracy: (test=0.867) total time=   1.3s
# [CV 5/5] END clf__n_neighbors=4, pca__n_components=100; accuracy: (test=0.884) total time=   1.3s
# [CV 1/5] END clf__n_neighbors=4, pca__n_components=150; accuracy: (test=0.805) total time=   1.7s
# [CV 2/5] END clf__n_neighbors=4, pca__n_components=150; accuracy: (test=0.842) total time=   1.6s
# [CV 3/5] END clf__n_neighbors=4, pca__n_components=150; accuracy: (test=0.893) total time=   1.7s
# [CV 4/5] END clf__n_neighbors=4, pca__n_components=150; accuracy: (test=0.871) total time=   1.7s
# [CV 5/5] END clf__n_neighbors=4, pca__n_components=150; accuracy: (test=0.891) total time=   1.7s
# [CV 1/5] END clf__n_neighbors=5, pca__n_components=50; accuracy: (test=0.818) total time=   0.8s
# [CV 2/5] END clf__n_neighbors=5, pca__n_components=50; accuracy: (test=0.835) total time=   0.8s
# [CV 3/5] END clf__n_neighbors=5, pca__n_components=50; accuracy: (test=0.873) total time=   0.8s
# [CV 4/5] END clf__n_neighbors=5, pca__n_components=50; accuracy: (test=0.871) total time=   0.8s
# [CV 5/5] END clf__n_neighbors=5, pca__n_components=50; accuracy: (test=0.876) total time=   0.8s
# [CV 1/5] END clf__n_neighbors=5, pca__n_components=100; accuracy: (test=0.805) total time=   1.3s
# [CV 2/5] END clf__n_neighbors=5, pca__n_components=100; accuracy: (test=0.829) total time=   1.3s
# [CV 3/5] END clf__n_neighbors=5, pca__n_components=100; accuracy: (test=0.871) total time=   1.3s
# [CV 4/5] END clf__n_neighbors=5, pca__n_components=100; accuracy: (test=0.856) total time=   1.3s
# [CV 5/5] END clf__n_neighbors=5, pca__n_components=100; accuracy: (test=0.885) total time=   1.3s
# [CV 1/5] END clf__n_neighbors=5, pca__n_components=150; accuracy: (test=0.793) total time=   1.6s
# [CV 2/5] END clf__n_neighbors=5, pca__n_components=150; accuracy: (test=0.818) total time=   1.6s
# [CV 3/5] END clf__n_neighbors=5, pca__n_components=150; accuracy: (test=0.871) total time=   1.7s
# [CV 4/5] END clf__n_neighbors=5, pca__n_components=150; accuracy: (test=0.847) total time=   1.6s
# [CV 5/5] END clf__n_neighbors=5, pca__n_components=150; accuracy: (test=0.878) total time=   1.6s

# %%
# print best parameter after tuning
print(KNN_model.best_params_)
 
# print how our model looks after hyper-parameter tuning
print(KNN_model.best_estimator_)
# Out:
# {'clf__n_neighbors': 1, 'pca__n_components': 100}
# Pipeline(steps=[('scalar', StandardScaler()), ('pca', PCA(n_components=100)),
#                 ('clf', KNeighborsClassifier(n_neighbors=1))])

# %%
confusion_matrix = ConfusionMatrixDisplay.from_estimator(KNN_model, x_test, y_test, normalize='true')
confusion_matrix.figure_.savefig('./confusion_matrix_multi_SVM.png')
pred = KNN_model.predict(x_test)
score = accuracy_score(y_test, pred)
print('accuracy: ', score)

# print classification report
print(classification_report(y_test, pred))
plt.show()
# Out:
# accuracy:  0.9133333333333333
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.90       258
#            1       0.83      0.85      0.84       129
#            2       0.92      0.89      0.91       257
#            3       0.96      0.97      0.96       256
#
#     accuracy                           0.91       900
#    macro avg       0.90      0.91      0.90       900
# weighted avg       0.91      0.91      0.91       900
